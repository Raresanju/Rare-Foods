# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

from bson.objectid import ObjectId
import time
import datetime

# %%
# !pip install colorama
# Out:
# Requirement already satisfied: colorama in c:\users\valav\anaconda3\envs\gpu2\lib\site-packages (0.4.4)

# %%
with open('intents.json') as file:
    data = json.load(file)
    
train_patterns = [] # patterns
train_intents = [] # tags
labels = [] #tags
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        train_patterns.append(pattern)
        train_intents.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
print("train_patterns :", train_patterns[100])
print("train_intents :", train_intents[100])
print("num_classes :", num_classes)
# Out:
# train_patterns : I am hungry
# train_intents : menu
# num_classes : 23

# %% [markdown]
# ### Then we use `LabelEncoder()` function provided by scikit-learn to convert the target labels into a model understandable form.

# %%
label_encoder = LabelEncoder()
label_encoder.fit(train_intents)
train_intents = label_encoder.transform(train_intents)

# %% [markdown]
# ## Vectorization
#
# - We vectorize our text data corpus by using the “Tokenizer” class and it allows us to limit our vocabulary size up to some defined number.
#
# - When we use this class for the text pre-processing task, by default all punctuations will be removed, turning the texts into space-separated sequences of words, and these sequences are then split into lists of tokens.
#
# - They will then be indexed or vectorized. We can also add “oov_token” which is a value for “out of token” to deal with out of vocabulary words(tokens) at inference time.
#
# - The “pad_sequences” method is used to make all the training text sequences into the same size.

# %%
vocab_size = 11250
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=None)
tokenizer.fit_on_texts(train_patterns)

word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(train_patterns)

padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
print("train_patterns :", train_patterns[99])
print("sequences: ", sequences[99])
# Out:
# train_patterns : Im damn hungry
# sequences:  [204, 205, 128]

# %% [markdown]
# ## 1) Here, we have to deal with multiple inputs or multiple outputs. Hence, we'll use `Keras` `Sequential()` model.
#
# read more : [Kears Sequential model details](https://keras.io/guides/sequential_model/)
#
# ## 2) Loss Function: `sparse_categorical_crossentropy` : We are using this crossentropy loss function when there are two or more label classes.
# read more about [sparse_categorical_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 16)            180000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 23)                391
# =================================================================
# Total params: 180,935
# Trainable params: 180,935
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(train_intents), epochs=epochs)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1304 - accuracy: 0.1301
# Epoch 2/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.1190 - accuracy: 0.1301
# Epoch 3/500
# 12/12 [==============================] - 0s 1ms/step - loss: 3.1077 - accuracy: 0.1301
# Epoch 4/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0931 - accuracy: 0.1301
# Epoch 5/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0745 - accuracy: 0.1301
# Epoch 6/500
# 12/12 [==============================] - 0s 1ms/step - loss: 3.0521 - accuracy: 0.1301
# Epoch 7/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0242 - accuracy: 0.1301
# Epoch 8/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.9935 - accuracy: 0.1301
# Epoch 9/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.9590 - accuracy: 0.1301
# Epoch 10/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.9296 - accuracy: 0.1301
# Epoch 11/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9063 - accuracy: 0.1301
# Epoch 12/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8888 - accuracy: 0.1301
# Epoch 13/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8747 - accuracy: 0.1301
# Epoch 14/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8631 - accuracy: 0.1355
# Epoch 15/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8488 - accuracy: 0.1436
# Epoch 16/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8363 - accuracy: 0.1436
# Epoch 17/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8239 - accuracy: 0.1436
# Epoch 18/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8069 - accuracy: 0.1436
# Epoch 19/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7918 - accuracy: 0.1436
# Epoch 20/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.7770 - accuracy: 0.1436
# Epoch 21/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.7584 - accuracy: 0.1436
# Epoch 22/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.7409 - accuracy: 0.1436
# Epoch 23/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7204 - accuracy: 0.1436
# Epoch 24/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6957 - accuracy: 0.1436
# Epoch 25/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6725 - accuracy: 0.1463
# Epoch 26/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.6447 - accuracy: 0.1491
# Epoch 27/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.6199 - accuracy: 0.1599
# Epoch 28/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.5938 - accuracy: 0.1762
# Epoch 29/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.5669 - accuracy: 0.1816
# Epoch 30/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.5407 - accuracy: 0.1816
# Epoch 31/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.5157 - accuracy: 0.1843
# Epoch 32/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.4874 - accuracy: 0.1924
# Epoch 33/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4629 - accuracy: 0.1924
# Epoch 34/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4364 - accuracy: 0.2033
# Epoch 35/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4053 - accuracy: 0.2005
# Epoch 36/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3764 - accuracy: 0.2168
# Epoch 37/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3481 - accuracy: 0.2249
# Epoch 38/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.3171 - accuracy: 0.2331
# Epoch 39/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.2869 - accuracy: 0.2493
# Epoch 40/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2545 - accuracy: 0.2493
# Epoch 41/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.2255 - accuracy: 0.2520
# Epoch 42/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1942 - accuracy: 0.2575
# Epoch 43/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.1630 - accuracy: 0.2602
# Epoch 44/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.1316 - accuracy: 0.2520
# Epoch 45/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0988 - accuracy: 0.2710
# Epoch 46/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0675 - accuracy: 0.2927
# Epoch 47/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0363 - accuracy: 0.2818
# Epoch 48/500
# 12/12 [==============================] - 0s 1ms/step - loss: 2.0041 - accuracy: 0.2927
# Epoch 49/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9731 - accuracy: 0.3171
# Epoch 50/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.9411 - accuracy: 0.3171
# Epoch 51/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.9067 - accuracy: 0.3279
# Epoch 52/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8761 - accuracy: 0.3198
# Epoch 53/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8424 - accuracy: 0.3171
# Epoch 54/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8104 - accuracy: 0.3306
# Epoch 55/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7803 - accuracy: 0.3469
# Epoch 56/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7490 - accuracy: 0.3577
# Epoch 57/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7209 - accuracy: 0.4011
# Epoch 58/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6916 - accuracy: 0.3848
# Epoch 59/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.6613 - accuracy: 0.4065
# Epoch 60/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6300 - accuracy: 0.4092
# Epoch 61/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6016 - accuracy: 0.4715
# Epoch 62/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5764 - accuracy: 0.4580
# Epoch 63/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5465 - accuracy: 0.5014
# Epoch 64/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5171 - accuracy: 0.5203
# Epoch 65/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4926 - accuracy: 0.5122
# Epoch 66/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4702 - accuracy: 0.5610
# Epoch 67/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4400 - accuracy: 0.5230
# Epoch 68/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4136 - accuracy: 0.5339
# Epoch 69/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3852 - accuracy: 0.5664
# Epoch 70/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3600 - accuracy: 0.5772
# Epoch 71/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.3361 - accuracy: 0.5935
# Epoch 72/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3178 - accuracy: 0.5908
# Epoch 73/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2912 - accuracy: 0.5881
# Epoch 74/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2651 - accuracy: 0.6450
# Epoch 75/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2427 - accuracy: 0.6396
# Epoch 76/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2181 - accuracy: 0.6233
# Epoch 77/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1949 - accuracy: 0.6423
# Epoch 78/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1707 - accuracy: 0.6531
# Epoch 79/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1487 - accuracy: 0.6504
# Epoch 80/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1273 - accuracy: 0.6450
# Epoch 81/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1043 - accuracy: 0.6829
# Epoch 82/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0866 - accuracy: 0.6829
# Epoch 83/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0699 - accuracy: 0.6829
# Epoch 84/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0487 - accuracy: 0.7127
# Epoch 85/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0308 - accuracy: 0.7046
# Epoch 86/500
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0078 - accuracy: 0.6938
# Epoch 87/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9902 - accuracy: 0.7073
# Epoch 88/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9696 - accuracy: 0.7317
# Epoch 89/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9479 - accuracy: 0.7425
# Epoch 90/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9325 - accuracy: 0.7398
# Epoch 91/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9113 - accuracy: 0.7344
# Epoch 92/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8928 - accuracy: 0.7534
# Epoch 93/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8752 - accuracy: 0.7778
# Epoch 94/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8606 - accuracy: 0.7724
# Epoch 95/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8453 - accuracy: 0.7642
# Epoch 96/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8332 - accuracy: 0.7751
# Epoch 97/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8151 - accuracy: 0.7724
# Epoch 98/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7968 - accuracy: 0.8049
# Epoch 99/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7834 - accuracy: 0.8022
# Epoch 100/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7684 - accuracy: 0.7832
# Epoch 101/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7555 - accuracy: 0.8049
# Epoch 102/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.7995
# Epoch 103/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7274 - accuracy: 0.8049
# Epoch 104/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7128 - accuracy: 0.8211
# Epoch 105/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7028 - accuracy: 0.8266
# Epoch 106/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.8347
# Epoch 107/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6758 - accuracy: 0.8293
# Epoch 108/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6654 - accuracy: 0.8347
# Epoch 109/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6509 - accuracy: 0.8455
# Epoch 110/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6384 - accuracy: 0.8482
# Epoch 111/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.8537
# Epoch 112/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6185 - accuracy: 0.8537
# Epoch 113/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6064 - accuracy: 0.8564
# Epoch 114/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5951 - accuracy: 0.8509
# Epoch 115/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.8618
# Epoch 116/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5739 - accuracy: 0.8699
# Epoch 117/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5627 - accuracy: 0.8726
# Epoch 118/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5514 - accuracy: 0.8699
# Epoch 119/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5456 - accuracy: 0.8699
# Epoch 120/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5330 - accuracy: 0.8753
# Epoch 121/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.8780
# Epoch 122/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5138 - accuracy: 0.8780
# Epoch 123/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.8862
# Epoch 124/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.8808
# Epoch 125/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4879 - accuracy: 0.8862
# Epoch 126/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4773 - accuracy: 0.8889
# Epoch 127/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4706 - accuracy: 0.8916
# Epoch 128/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4647 - accuracy: 0.8916
# Epoch 129/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4525 - accuracy: 0.8997
# Epoch 130/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.8916
# Epoch 131/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.9024
# Epoch 132/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4283 - accuracy: 0.8970
# Epoch 133/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4215 - accuracy: 0.9051
# Epoch 134/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4153 - accuracy: 0.9024
# Epoch 135/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4074 - accuracy: 0.9024
# Epoch 136/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4010 - accuracy: 0.9133
# Epoch 137/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8997
# Epoch 138/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3851 - accuracy: 0.9106
# Epoch 139/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.3784 - accuracy: 0.9268
# Epoch 140/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3711 - accuracy: 0.9268
# Epoch 141/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.9106
# Epoch 142/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3583 - accuracy: 0.9187
# Epoch 143/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3533 - accuracy: 0.9133
# Epoch 144/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.3470 - accuracy: 0.9187
# Epoch 145/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3421 - accuracy: 0.9241
# Epoch 146/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3330 - accuracy: 0.9322
# Epoch 147/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3278 - accuracy: 0.9539
# Epoch 148/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3199 - accuracy: 0.9512
# Epoch 149/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3154 - accuracy: 0.9458
# Epoch 150/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3105 - accuracy: 0.9268
# Epoch 151/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3051 - accuracy: 0.9566
# Epoch 152/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2994 - accuracy: 0.9485
# Epoch 153/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.9539
# Epoch 154/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2876 - accuracy: 0.9566
# Epoch 155/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.9593
# Epoch 156/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.2774 - accuracy: 0.9593
# Epoch 157/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2731 - accuracy: 0.9593
# Epoch 158/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2681 - accuracy: 0.9621
# Epoch 159/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2620 - accuracy: 0.9675
# Epoch 160/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2574 - accuracy: 0.9621
# Epoch 161/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2538 - accuracy: 0.9675
# Epoch 162/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.9729
# Epoch 163/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.9756
# Epoch 164/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2401 - accuracy: 0.9702
# Epoch 165/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9702
# Epoch 166/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9702
# Epoch 167/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2264 - accuracy: 0.9702
# Epoch 168/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2205 - accuracy: 0.9783
# Epoch 169/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2208 - accuracy: 0.9810
# Epoch 170/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2122 - accuracy: 0.9783
# Epoch 171/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2086 - accuracy: 0.9729
# Epoch 172/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2043 - accuracy: 0.9729
# Epoch 173/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2001 - accuracy: 0.9810
# Epoch 174/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1977 - accuracy: 0.9810
# Epoch 175/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1932 - accuracy: 0.9837
# Epoch 176/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1900 - accuracy: 0.9837
# Epoch 177/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1869 - accuracy: 0.9783
# Epoch 178/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1845 - accuracy: 0.9837
# Epoch 179/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1793 - accuracy: 0.9756
# Epoch 180/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.9837
# Epoch 181/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1714 - accuracy: 0.9864
# Epoch 182/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 0.9837
# Epoch 183/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1639 - accuracy: 0.9864
# Epoch 184/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1607 - accuracy: 0.9864
# Epoch 185/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1586 - accuracy: 0.9864
# Epoch 186/500
# 12/12 [==============================] - 0s 953us/step - loss: 0.1542 - accuracy: 0.9864
# Epoch 187/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1507 - accuracy: 0.9919
# Epoch 188/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1479 - accuracy: 0.9864
# Epoch 189/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1463 - accuracy: 0.9919
# Epoch 190/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1424 - accuracy: 0.9892
# Epoch 191/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1419 - accuracy: 0.9864
# Epoch 192/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9919
# Epoch 193/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1334 - accuracy: 0.9946
# Epoch 194/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1308 - accuracy: 0.9973
# Epoch 195/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1287 - accuracy: 0.9946
# Epoch 196/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1254 - accuracy: 0.9919
# Epoch 197/500
# 12/12 [==============================] - 0s 945us/step - loss: 0.1231 - accuracy: 0.9973
# Epoch 198/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1209 - accuracy: 0.9973
# Epoch 199/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9973
# Epoch 200/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1152 - accuracy: 0.9973
# Epoch 201/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1131 - accuracy: 0.9973
# Epoch 202/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1100 - accuracy: 0.9973
# Epoch 203/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1081 - accuracy: 0.9973
# Epoch 204/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 0.9973
# Epoch 205/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9973
# Epoch 206/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1010 - accuracy: 0.9973
# Epoch 207/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9973
# Epoch 208/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0975 - accuracy: 0.9973
# Epoch 209/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0966 - accuracy: 0.9973
# Epoch 210/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9973
# Epoch 211/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0909 - accuracy: 0.9973
# Epoch 212/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0894 - accuracy: 0.9973
# Epoch 213/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0876 - accuracy: 0.9973
# Epoch 214/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9973
# Epoch 215/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 216/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9973
# Epoch 217/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 1.0000
# Epoch 218/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 1.0000
# Epoch 219/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 220/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0752 - accuracy: 1.0000
# Epoch 221/500
# 12/12 [==============================] - 0s 991us/step - loss: 0.0738 - accuracy: 1.0000
# Epoch 222/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0717 - accuracy: 1.0000
# Epoch 223/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 224/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0687 - accuracy: 1.0000
# Epoch 225/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0671 - accuracy: 1.0000
# Epoch 226/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 227/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 1.0000
# Epoch 228/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 229/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 230/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 231/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0592 - accuracy: 1.0000
# Epoch 232/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 1.0000
# Epoch 233/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 234/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 235/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 236/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 237/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 238/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 239/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0505 - accuracy: 1.0000
# Epoch 240/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 241/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 242/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 243/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 244/500
# 12/12 [==============================] - 0s 911us/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 245/500
# 12/12 [==============================] - 0s 959us/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 246/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 247/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 248/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 249/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 250/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 251/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 252/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 253/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 254/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 255/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 256/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 257/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 258/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 259/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 260/500
# 12/12 [==============================] - 0s 969us/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 261/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 1.0000
# Epoch 262/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 263/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 264/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 265/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 266/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 267/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 268/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 269/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 270/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 271/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 272/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 273/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 274/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 275/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 276/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 277/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 278/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 279/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 280/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 281/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 282/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 283/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 284/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 285/500
# 12/12 [==============================] - 0s 950us/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 286/500
# 12/12 [==============================] - 0s 959us/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 287/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 288/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 289/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 290/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 291/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 292/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 293/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 294/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 295/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 296/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 297/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 298/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 299/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 300/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 301/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 302/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 303/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 304/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 305/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 306/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 307/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 308/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 309/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 310/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 311/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 312/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 313/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 314/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 315/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 316/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 317/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 318/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 319/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 320/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 321/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 322/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 323/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 324/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 325/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 326/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 327/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 328/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 329/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 330/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 331/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 332/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 333/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 334/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 335/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 336/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 337/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 338/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 339/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 340/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 341/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 342/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 343/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 344/500
# 12/12 [==============================] - 0s 917us/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 345/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 346/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 347/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 348/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 349/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 350/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 351/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 352/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 353/500
# 12/12 [==============================] - 0s 1000us/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 354/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 355/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 356/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 357/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 358/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 359/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 360/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 361/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 362/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 363/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 364/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 365/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 366/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 367/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 368/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 369/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 370/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 371/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 372/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 373/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 374/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 375/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 376/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 377/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 378/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 379/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 380/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 381/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 382/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 383/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 384/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 385/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 386/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 387/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 388/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 389/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 390/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 391/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 392/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 393/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 394/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 395/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 396/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 397/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 398/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 399/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 400/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 401/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 402/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 403/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 404/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 405/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 406/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 407/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 408/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 409/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 410/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 411/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 412/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 413/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 414/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 415/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 416/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 417/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 418/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 419/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 420/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 421/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 422/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 423/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 424/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 425/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 426/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 427/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 428/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 429/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 430/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 431/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 432/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 433/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 434/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 435/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 436/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 437/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 438/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 439/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 440/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 441/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 442/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 443/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 444/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 445/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 446/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 447/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 448/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 449/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 450/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 451/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 452/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 453/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 454/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 455/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 456/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 457/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 458/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 459/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 460/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 461/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 462/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 463/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 464/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 465/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 466/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 467/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 468/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 469/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 470/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 471/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 472/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 473/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 474/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 475/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 476/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 477/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 478/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 479/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 480/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 481/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 482/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 483/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 484/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 485/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 486/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 487/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 488/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 489/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 490/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 491/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 492/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 493/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 494/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 495/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 496/500
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 497/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 498/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 499/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 500/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000

# %%
history_dict = history.history

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")


loss_values = history_dict['loss']
#val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
#plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
#val_accuracy_values=history_dict['val_accuracy']
#plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred = model.predict(padded_sequences)
y_result=[]
for i in y_pred:
    max_value = max(i)
    #print(max_value)
    y_result.append(np.where(i == max_value)[0][0])





from sklearn.metrics import confusion_matrix
#CM matrix for training data
plt.figure(figsize=(12,12))

matrix_nn = confusion_matrix(y_result, np.array(train_intents))

sns.heatmap(matrix_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ## Save the models
#
# We are saving 3 different things separately
# - Classification model
# - fitted Tokenizer object
# - fitted label encoder object

# %%
# saving model
model.save("chat_model")

import pickle

# saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

# saving label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(label_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# WARNING:tensorflow:From c:\Users\valav\anaconda3\envs\gpu2\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\Users\valav\anaconda3\envs\gpu2\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\valav\anaconda3\envs\gpu2\lib\site-packages (4.1.1)

# %%
# !pip show pymongo
# !pip show bson
# Out:
# Name: pymongo
# Version: 4.1.1
# Summary: Python driver for MongoDB <http://www.mongodb.org>
# Home-page: http://github.com/mongodb/mongo-python-driver
# Author: The MongoDB Python Team
# Author-email:
# License: Apache License, Version 2.0
# Location: c:\users\valav\anaconda3\envs\gpu2\lib\site-packages
# Requires:
# Required-by:
# WARNING: Package(s) not found: bson

# %%
import json
import random
import datetime
import pymongo
import uuid

# %%
import pymongo
import urllib.parse

# Make sure Settings->Network Access has correct settings

username = urllib.parse.quote_plus("valavalasanjeevi")  # Replace with your MongoDB username
password = urllib.parse.quote_plus("sanju")  # Replace with your MongoDB password
cluster_address = "cluster0.ukzqrkk.mongodb.net"  # Replace with your cluster address
database_name = "delishapp"  # Replace with your database name

URI = f"mongodb+srv://{username}:{password}@{cluster_address}/{database_name}?retryWrites=true&w=majority"
client = pymongo.MongoClient(URI, connect=False)

db = client[database_name]
menu_collection = db["menu"]
feedback_collection = db["feedback"]
order_collection = db["Orders"]
bookings_collection = db["bookings"]

# Check the connection
try:
    client.admin.command('ping')
    print("Connected to MongoDB!")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connected to MongoDB!

# %%
seat_count = 50
import urllib.parse
# Make sure Settings->Network Access has correct settings


username = urllib.parse.quote_plus("valavalasanjeevi")  # Replace with your MongoDB username
password = urllib.parse.quote_plus("sanju")  # Replace with your MongoDB password
cluster_address = "cluster0.ukzqrkk.mongodb.net"  # Replace with your cluster address
database_name = "delishapp"  # Replace with your database name

URI = f"mongodb+srv://{username}:{password}@{cluster_address}/{database_name}?retryWrites=true&w=majority"
client = pymongo.MongoClient(URI, connect=False)

db = client[database_name]
menu_collection = db["menu"]
feedback_collection = db["feedback"]
order_collection = db["Orders"]
bookings_collection = db["bookings"]

# %%
query = {"mainmenu": "Y"}

veg_data = menu_collection.find(query)
x=[]
for i in veg_data:
    if (i.get("breakfast")=="N") == True:
        x.append(i.get("item"))
x
# Out:
# []

# %%
# Order
def record_order(message):
    print("Saving customers order")
    print(message)
    items_ = message.split("||")


    arr_dict={}
    for j,i in enumerate(items_[1:-1]):
 
        str1_ = i.split(",")
        dict_name='item {}'.format(j)
        arr_dict[dict_name]={}
    
        arr_dict[dict_name]['item'] = str1_[0].split(":")[1]
        arr_dict[dict_name]['price'] = str1_[1].split(":")[1]
        arr_dict[dict_name]['quantity'] = str1_[2].split(":")[1]
        #print(arr_dict[dict_name])
    

    
    arr_dict["Total Price"]={}
    arr_dict["order_details"]={}
         
    orderplaced_id = str(uuid.uuid4())
    arr_dict["Total Price"]["total bill"] = items_[0].split(":")[1]
    arr_dict["order_details"]["OrderID"] = orderplaced_id
    
    # Adding the ordering time:
    now_ = datetime.datetime.now()
    booking_time_ = now_.strftime("%Y-%m-%d %H:%M:%S")
    arr_dict["order_details"]["OrderTime"] = booking_time_
    arr_dict["order_details"]["OrderStatus"]="placed"
   
    
    
    
    # Make the array of nested dictionary
    item_dict=[]
    item_dict.append(arr_dict)
    
    nested_dictionary =item_dict
    order_collection.insert_many(nested_dictionary)
    return orderplaced_id
    # get the order id
    
    
    
# Cancel Order
def cancel_order(order_id):
    print(order_id)
    result={}
    status_=""
    query = {"order_details.OrderID": order_id}
    doc_ = order_collection.find(query)
    
    for x in doc_:
        result = x
        
    print(result)
    
    
   
        
    if result:
        status_=result["order_details"]["OrderStatus"]
        od_id = result["_id"]
        print(od_id)
        print(status_)
        if status_ == 'placed':
            


            order_itemX=['Total Price','_id','order_details', 'OrderStatus']
            cancelStr = "Cancelling your order with : "
            for i in result:
                if i not in order_itemX:
                    cancelStr+= "("+result[i]['quantity'] + "-" + result[i]['item'] + ") "
            
   
            cancelStr+="💰 ₹" + result['Total Price']['total bill'] + " will be refunded to your account."
            
           
            order_collection.replace_one({"_id" :od_id },  {"order_details":{"OrderID":order_id,"OrderStatus":"canceled"}})
            update_data = order_collection.find_one({"_id":od_id})
            print(update_data["order_details"]["OrderStatus"])
            
            return cancelStr
        
        else:
            return "🚫 This order has been canceled already."
    
    else:
        return "Please enter correct Order ID and 📌before entering order ID send the 'cancel Order' message again." 


# Order Status


def order_status(order_id):
    making = "00:05:00"
    made = "00:20:00"
    delivery = "00:35:00"
    
    print(order_id)
    result={}
    order_status=""
    status_=""
    query = {"order_details.OrderID": order_id}
    doc_ = order_collection.find(query)
    
    for x in doc_:
        result = x
        
    print(result)

    if result:
        status_=result["order_details"]["OrderStatus"]
        od_id = result["_id"]
        print(od_id)
        print(status_)
        if status_ == 'placed':
            order_t = datetime.datetime.strptime(result["order_details"]["OrderTime"].split(" ")[1], "%H:%M:%S")
            seconds_ = (datetime.datetime.now() - order_t).seconds
            time_gap = time.strftime("%H:%M:%S", time.gmtime(seconds_))
            
            #> 20 minutes
            if (datetime.datetime.strptime(time_gap, "%H:%M:%S") > datetime.datetime.strptime(made, "%H:%M:%S")) and (datetime.datetime.strptime(time_gap, "%H:%M:%S") < datetime.datetime.strptime(delivery, "%H:%M:%S")):
                order_status = "Your order is on the way. 🚀"

            #between 5-20 minutes
            elif (datetime.datetime.strptime(time_gap, "%H:%M:%S") <= datetime.datetime.strptime(made, "%H:%M:%S")) and (datetime.datetime.strptime(time_gap, "%H:%M:%S") > datetime.datetime.strptime(making, "%H:%M:%S")):
                order_status = "Your food is being prepared. 🍜"
                
            #<5 minutes
            elif datetime.datetime.strptime(time_gap, "%H:%M:%S") < datetime.datetime.strptime(making, "%H:%M:%S"):
                order_status = "You order has been placed and chef is about to start cooking. 👩‍🍳"

            #>35 minutes
            elif datetime.datetime.strptime(time_gap, "%H:%M:%S") > datetime.datetime.strptime(delivery, "%H:%M:%S"):
                order_status = "We regret for delay in your food delivery, please contact our delivery agent or ask for refund.We assure you of speedy and safe delivery nect time. 🙏"
    
            else:
                order_status = "Food is already delivered.🍱"
            
            
            

            return order_status
        
        else:
            return "🚫 This order has been canceled already."
    
    else:
        return "Please enter correct Order ID and 📌before entering order ID send the 'Order Status' message again." 


 
    
    
# Book a table:
seat_count = 50
def book_table():
    global seat_count
    seat_count = seat_count - 1
    booking_id = str(uuid.uuid4())
    now = datetime.datetime.now()
    booking_time = now.strftime("%Y-%m-%d %H:%M:%S")
    booking_doc = {"booking_id": booking_id, "booking_time": booking_time}
    bookings_collection.insert_one(booking_doc)
    return booking_id


def get_specific_response(tag):
    for intent in data['intents']:
        if intent['tag'] == tag:
            responses = intent['responses']
    response = random.choice(responses)
    return response


def show_menu():
    all_items = menu_collection.distinct('item')
    response = ', '.join(all_items)
    return response

def record_feedback(message, type):
    print("Recording your feedback")
    feedback_doc = {"feedback_string": message, "type": type}
    feedback_collection.insert_one(feedback_doc)
    
def recipe_enquiry(inp):
    response=""
    for i in menu_collection.distinct('item'):
        if i.lower() in inp.lower():
            #print(i)
            #if inp.lower()== i.lower():
        
            query_about= {"item":i}
            about = menu_collection.find(query_about)
            for j in about:
                response = j.get("details")
        
            
    if response =="":
        response = "I don't know much about this recipe! But, you can contact our restaurant for more details."
    return response


def suggest():
    day = datetime.datetime.now()
    day = day.strftime("%A")
    if day == "Monday":
        response = "I would recommend: Paneer Roll and Chicken Biryani"
    elif day == "Tuesday":
        response = "I would recommend: Cheese Grilled Sandwich and Chicken tripple rice"

    elif day == "Wednesday":
        response = "I would recommend: Egg Roll and Latte "

    elif day == "Thursday":
        response = "I would recommend: Mixed Fruit Juice and Chicken cheese sandwich"

    elif day == "Friday":
        response = "I would recommend: White Sauce Pasta and Cheese cake"

    elif day == "Saturday":
        response = "I would recommend: Chicken Roll and cold coffee"

    elif day == "Sunday":
        response = "I would recommend: Schezwan Rice and Manchurian"
    return response


def veg_menu():
    res=[]    
    query = {"veg": "Y"}
    b_query = {"Breads": "Y"}
    d_query = {"Desert": "Y"}
    i_query = {"icecreams_bev":"Y"}
    breads=[]
    deserts =[]
    ice_bev=[]


    b_doc = menu_collection.find(b_query)
    for x in b_doc:
        breads.append(x.get("item"))
    
    d_doc = menu_collection.find(d_query)
    for x in d_doc:
        deserts.append(x.get("item"))
    
    i_doc = menu_collection.find(i_query)
    for x in i_doc:
        ice_bev.append(x.get("item")) 
        
        
    veg_doc = menu_collection.find(query)
    for x in veg_doc:
        if x.get("item") not in exclude_items:
            res.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        
        
    return res



def nonveg_menu():
    re=[]
    query = {"nonveg": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        re.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return re




def breakfast_menu():
    br=[]
    query = {"breakfast": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        br.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return br

def bevrages_menu():
    bev=[]
    query = {"icecreams_bev": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        bev.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return bev

def desert_menu():
    de=[]
    query = {"Desert": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        de.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return de

def snacks_menu():
    sn=[]
    query = {"snacks": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        sn.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return sn


def main_menu():
    menu=[]
    query = {"mainmenu": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        menu.append(str(x.get("item")) +"\n")
   
    return menu

def offers():
    
    response = "Sorry there are no offers available now."
    return response

# %%
def generate_response(tag, user_input):
    global seat_count
    #tag = get_intent(message)
    response = ""
    if tag != "":
        if tag == "book_table":

            if seat_count > 0:
                booking_id = book_table()
                response = "Your table has been booked successfully :" + str(
                    booking_id)
            else:
                response = "Sorry we are sold out now!"


        elif tag == "available_tables":
            response = "Right now, there are " + str(seat_count) + " table(s) available."

        elif tag == "veg_enquiry":
            response ="Hey, You can discover our amazing vegetarian options in the Menu section on your left."

        elif tag == "nonveg_enquiry":
            response = "Hey, You can discover Non-vegetarian food options in the Menu section on your left."
            
        elif tag == "vegan_enquiry":
            response = "Sorry, We don't serve Vegan Food"

        elif tag == "offers":
            response =offers()

        elif tag == "suggest":
            
            response =suggest()
            response+="\n"+"Or else you can check our populars in the Menu section!!"

        elif tag == "recipe_enquiry":
            response =recipe_enquiry(user_input)

        elif tag == "menu":
            response="Checkout our lip-smacking food options on your left. Just add whichever food item you like." + "\n" + "worried about recipes and ingredients? ask me!!. I've got you covered 😎"
            
        elif tag == "Icecreams_bevrages":
            response = "Checkout Desserts option for the refreshing bevrages!! 🍨"
            
        elif tag == "Quick_Bites":
            #response1 = snacks_menu()
            #response2= breakfast_menu()
            #response3 = bevrages_menu()
            #response = response1 + response2 + response3
            response = "Hey, You can explore breakfast, Snacks and Desserts options on your left for some quick refreshments!!"
            
        elif tag == "positive_feedback":
            record_feedback(user_input, "positive")
            response = "Huzzah!!😍 Thank you so much for your valuable feedback. We look forward to serving you again!"

        elif "negative_feedback" == tag:
            record_feedback(user_input, "negative")
            response = "Thank you so much for your valuable feedback. We deeply regret the inconvenience. We have " \
                       "forwarded your concerns to the authority and hope to satisfy you better the next time! 🙏"
        # for other intents with pre-defined responses that can be pulled from dataset
        else:
            response = get_specific_response(tag)
    else:
        response = "Sorry! I didn't get it, please try to be more precise."
    return response

# %% [markdown]
# ### Load the model

# %%
def response_gen(message):
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([message]),truncating='post', maxlen=max_len))
    
    ## Find the intent
    tag = lbl_encoder.inverse_transform([np.argmax(result)])
    print(tag)

    for i in data['intents']:
        if i['tag'] == tag:
            output = generate_response(tag, message)
            
    return output

# %%
from flask import Flask, render_template, request, jsonify
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
import os

ORDER_ID=False

TEMPLATE_DIR = os.path.abspath('./templates')
STATIC_DIR = os.path.abspath('./static')

app = Flask(__name__) #


@app.route('/')
def index():
    return render_template('index.html')


@app.route('/get')
def get_bot_response():
    
    message = request.args.get('msg')
    #print(message)
    response = ""
    if message:
        if message.startswith("TotalPrice:"):
            print(message)
            o_id = record_order(message)
            id_res = "Your Order ID is : " + o_id + " Kindly remember this ID for the future reference."
            return id_res
        #Order Cancel
        elif message.endswith("-ORDERID"):
            # if intent is Cancel
            print(message)
            
            cancelOrderStr = cancel_order(message.split("-ORDERID")[0])
            
            return cancelOrderStr
        
        elif message.endswith("-STATUSID"):
            # if intent is Cancel
            print(message)
            
            statusOrderStr = order_status(message.split("-STATUSID")[0])
            
            return statusOrderStr
            
            
            
        else:
            response = response_gen(message)
            #print(response)
            
                
        
        return str(response)
    
    else:
        return "Missing Data!"
    


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item3.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item5.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item4.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item6.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item7.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item8.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item9.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /chatbot%20scriptsstaticimagesitem37.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item10.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item11.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item12.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item13.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item14.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item15.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item16.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item17.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:37] "GET /static/images/item18.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item19.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item24.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item23.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item22.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item20.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item21.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item25.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item26.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item27.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item28.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item29.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item30.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item31.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item32.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item33.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item34.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item37.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item35.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item36.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:38] "GET /static/images/item38.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item39.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item41.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item40.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item42.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item43.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item44.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /static/images/item45.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jul/2024 19:13:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [09/Jul/2024 19:13:47] "GET /get?msg=hello HTTP/1.1" 200 -
# ['greeting']
# 127.0.0.1 - - [09/Jul/2024 19:13:55] "GET /get?msg=book+a+table HTTP/1.1" 200 -
# ['book_table']

# %% [markdown]
# Mongodb reference: https://kb.objectrocket.com/category/mongo-db
